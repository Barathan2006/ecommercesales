# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Sales Transaction v.4a.csv")
df
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# ...

# %%
df.describe()
# Out:
#                Price       Quantity     CustomerNo
# count  536350.000000  536350.000000  536295.000000
# mean       12.662182       9.919347   15227.893178
# std         8.490450     216.662300    1716.582932
# min         5.130000  -80995.000000   12004.000000
# 25%        10.990000       1.000000   13807.000000
# 50%        11.940000       3.000000   15152.000000
# 75%        14.090000      10.000000   16729.000000
# max       660.620000   80995.000000   18287.000000

# %%
df.isnull().sum()
# Out:
# TransactionNo     0
# Date              0
# ProductNo         0
# ProductName       0
# Price             0
# Quantity          0
# CustomerNo       55
# Country           0
# dtype: int64

# %%
df["CustomerNo"].fillna(0,inplace=True)
# Out:
# C:\Users\barat\AppData\Local\Temp\ipykernel_14672\1655798786.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["CustomerNo"].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# TransactionNo    0
# Date             0
# ProductNo        0
# ProductName      0
# Price            0
# Quantity         0
# CustomerNo       0
# Country          0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
df['Country'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
    df.groupby("Country")["Price"].mean()
# Out:
# Country
# Australia               12.772938
# Austria                 13.733980
# Bahrain                 15.010000
# Belgium                 13.185282
# Brazil                  14.382903
# Canada                  12.353960
# Channel Islands         13.585199
# Cyprus                  19.160475
# Czech Republic          11.866786
# Denmark                 12.472885
# EIRE                    13.031650
# European Community      14.597241
# Finland                 12.617977
# France                  12.423259
# Germany                 12.597669
# Greece                  11.540149
# Hong Kong               13.361007
# Iceland                  7.869490
# Israel                  13.334533
# Italy                   13.323510
# Japan                   12.096092
# Lebanon                 15.771111
# Lithuania               13.066471
# Malta                   13.580336
# Netherlands             11.888781
# Norway                  12.611418
# Poland                  13.888333
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df["Date"], df["Price"])
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("Price Over Time")
plt.show()

# %%
corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True , cmap="coolwarm")

plt.show()

# %%
df
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
df.groupby("ProductName")["Quantity"].sum()
# Out:
# ProductName
# 10 Colour Spaceboy Pen              6406
# 12 Coloured Party Balloons          2114
# 12 Daisy Pegs In Wood Box            344
# 12 Egg House Painted Wood            148
# 12 Hanging Eggs Hand Painted          41
#                                     ...
# Zinc T-Light Holder Stars Small     5045
# Zinc Top 2 Door Wooden Shelf           8
# Zinc Willie Winkie Candle Stick     2922
# Zinc Wire Kitchen Organiser           30
# Zinc Wire Sweetheart Letter Tray      83
# Name: Quantity, Length: 3768, dtype: int64

# %%
df.groupby("ProductName")["TransactionNo"].count()
# Out:
# ProductName
# 10 Colour Spaceboy Pen              327
# 12 Coloured Party Balloons          167
# 12 Daisy Pegs In Wood Box            81
# 12 Egg House Painted Wood           100
# 12 Hanging Eggs Hand Painted          9
#                                    ...
# Zinc T-Light Holder Stars Small     278
# Zinc Top 2 Door Wooden Shelf         14
# Zinc Willie Winkie Candle Stick     273
# Zinc Wire Kitchen Organiser          16
# Zinc Wire Sweetheart Letter Tray     23
# Name: TransactionNo, Length: 3768, dtype: int64

# %%
df.groupby("ProductName").agg({
    "Quantity": "sum",
    "Price": "mean"
})
# Out:
#                                   Quantity      Price
# ProductName
# 10 Colour Spaceboy Pen                6406  10.995902
# 12 Coloured Party Balloons            2114  10.665389
# 12 Daisy Pegs In Wood Box              344  12.213086
# 12 Egg House Painted Wood              148  26.589100
# 12 Hanging Eggs Hand Painted            41   7.908889
# ...                                    ...        ...
# Zinc T-Light Holder Stars Small       5045  10.773597
# Zinc Top 2 Door Wooden Shelf             8  31.115000
# Zinc Willie Winkie Candle Stick       2922  10.839377
# Zinc Wire Kitchen Organiser             30  16.594375
# Zinc Wire Sweetheart Letter Tray        83  12.920000
#
# [3768 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

df['Price'].plot(kind='kde')
plt.xlabel("Price")
plt.title("Price Distribution (KDE)")
plt.show()

# %%
df.rename(columns={"ProductName":"Products"},inplace=True)

# %%
df
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                    Products  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
df.groupby('Products')['Price'].sum().plot(kind='bar', color='skyblue', label='Price')
df.groupby('Products')['Quantity'].sum().plot(kind='line', color='red', label='Products', secondary_y=True)
plt.title('Price vs Profit by Product')
plt.legend()
plt.show()
